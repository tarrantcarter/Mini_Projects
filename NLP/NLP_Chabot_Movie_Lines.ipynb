# %% [markdown]
# ## In this assignment, you'll work with a dataset called Cornell Movie--Dialogs Corpus, which was released by the Cornell University. The dataset contains conversations from more than 600 movies.

# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import nltk
import spacy
import re

# %%
# !pip install --ignore-installed PyYAML
# !pip install chatterbot
# !pip install chatterbot-corpus
# Out:
# Processing /Users/tarrantcarter/Library/Caches/pip/wheels/13/90/db/290ab3a34f2ef0b5a0f89235dc2d40fea83e77de84ed2dc05c/PyYAML-5.3.1-cp38-cp38-macosx_10_9_x86_64.whl
# Installing collected packages: PyYAML
# Successfully installed PyYAML-5.3.1
# Collecting chatterbot
#   Using cached ChatterBot-1.0.5-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: nltk<4.0,>=3.2 in /Users/tarrantcarter/.local/lib/python3.8/site-packages (from chatterbot) (3.5)
# Collecting pint>=0.8.1
#   Using cached Pint-0.16.1-py2.py3-none-any.whl (205 kB)
# Collecting pyyaml<5.2,>=5.1
#   Downloading PyYAML-5.1.2.tar.gz (265 kB)
#      |████████████████████████████████| 265 kB 329 kB/s eta 0:00:01
# Collecting mathparse<0.2,>=0.1
#   Using cached mathparse-0.1.2-py3-none-any.whl (7.2 kB)
# Collecting pymongo<4.0,>=3.3
#   Using cached pymongo-3.11.2-cp38-cp38-macosx_10_9_x86_64.whl (380 kB)
# Collecting spacy<2.2,>=2.1
#   Using cached spacy-2.1.9.tar.gz (30.7 MB)
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/tarrantcarter/miniconda3/bin/python /Users/tarrantcarter/miniconda3/lib/python3.8/site-packages/pip install --ignore-installed --no-user --prefix /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-build-env-cuhumo8y/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'wheel>0.32.0,<0.33.0' Cython 'cymem>=2.0.2,<2.1.0' 'preshed>=2.0.1,<2.1.0' 'murmurhash>=0.28.0,<1.1.0' 'thinc>=7.0.8,<7.1.0'
#        cwd: None
#   Complete output (1314 lines):
#   Collecting setuptools
#     Using cached setuptools-51.1.1-py3-none-any.whl (2.0 MB)
#   Collecting wheel<0.33.0,>0.32.0
#     Using cached wheel-0.32.3-py2.py3-none-any.whl (21 kB)
#   Collecting Cython
#     Using cached Cython-0.29.21-cp38-cp38-macosx_10_9_x86_64.whl (1.9 MB)
#   Collecting cymem<2.1.0,>=2.0.2
#     Using cached cymem-2.0.5-cp38-cp38-macosx_10_9_x86_64.whl (31 kB)
#   Processing /Users/tarrantcarter/Library/Caches/pip/wheels/5a/d0/29/7f6993a759349eae3d0ecca7e2fbc88acdd8650b25e6c6ad8a/preshed-2.0.1-cp38-cp38-macosx_10_9_x86_64.whl
#   Collecting murmurhash<1.1.0,>=0.28.0
#     Using cached murmurhash-1.0.5-cp38-cp38-macosx_10_9_x86_64.whl (18 kB)
#   Processing /Users/tarrantcarter/Library/Caches/pip/wheels/f4/5b/cc/8a96be826c5d22ca28e3c30f785b22edc57ffb2d349fa780be/thinc-7.0.8-cp38-cp38-macosx_10_9_x86_64.whl
#   Collecting numpy>=1.7.0
#     Using cached numpy-1.19.4-cp38-cp38-macosx_10_9_x86_64.whl (15.3 MB)
#   Collecting tqdm<5.0.0,>=4.10.0
#     Using cached tqdm-4.55.0-py2.py3-none-any.whl (68 kB)
#   Collecting plac<1.0.0,>=0.9.6
#     Using cached plac-0.9.6-py2.py3-none-any.whl (20 kB)
#   Collecting srsly<1.1.0,>=0.0.6
#     Using cached srsly-1.0.5-cp38-cp38-macosx_10_9_x86_64.whl (177 kB)
#   Collecting blis<0.3.0,>=0.2.1
#     Using cached blis-0.2.4.tar.gz (1.5 MB)
#   Collecting wasabi<1.1.0,>=0.0.9
#     Using cached wasabi-0.8.0-py3-none-any.whl (23 kB)
#   Building wheels for collected packages: blis
#     Building wheel for blis (setup.py): started
#     Building wheel for blis (setup.py): still running...
#     Building wheel for blis (setup.py): still running...
#     Building wheel for blis (setup.py): still running...
#     Building wheel for blis (setup.py): still running...
#     Building wheel for blis (setup.py): still running...
#     Building wheel for blis (setup.py): still running...
#     Building wheel for blis (setup.py): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarrantcarter/miniconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/setup.py'"'"'; __file__='"'"'/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-wheel-m1x560nz
#          cwd: /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/
#     Complete output (628 lines):
#     BLIS_COMPILER? None
#     running bdist_wheel
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-x86_64-3.8
#     creating build/lib.macosx-10.9-x86_64-3.8/blis
#     copying blis/benchmark.py -> build/lib.macosx-10.9-x86_64-3.8/blis
#     copying blis/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/blis
#     copying blis/about.py -> build/lib.macosx-10.9-x86_64-3.8/blis
#     creating build/lib.macosx-10.9-x86_64-3.8/blis/tests
#     copying blis/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/blis/tests
#     copying blis/tests/test_dotv.py -> build/lib.macosx-10.9-x86_64-3.8/blis/tests
#     copying blis/tests/test_gemm.py -> build/lib.macosx-10.9-x86_64-3.8/blis/tests
#     copying blis/tests/common.py -> build/lib.macosx-10.9-x86_64-3.8/blis/tests
#     copying blis/cy.pyx -> build/lib.macosx-10.9-x86_64-3.8/blis
#     copying blis/py.pyx -> build/lib.macosx-10.9-x86_64-3.8/blis
#     copying blis/__init__.pxd -> build/lib.macosx-10.9-x86_64-3.8/blis
#     copying blis/cy.pxd -> build/lib.macosx-10.9-x86_64-3.8/blis
#     running build_ext
#     unix
#     py_compiler gcc
#     {'LS_COLORS': 'rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=30;41:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.Z=01;31:*.dz=01;31:*.gz=01;31:*.lrz=01;31:*.lz=01;31:*.lzo=01;31:*.xz=01;31:*.zst=01;31:*.tzst=01;31:*.bz2=01;31:*.bz=01;31:*.tbz=01;31:*.tbz2=01;31:*.tz=01;31:*.deb=01;31:*.rpm=01;31:*.jar=01;31:*.war=01;31:*.ear=01;31:*.sar=01;31:*.rar=01;31:*.alz=01;31:*.ace=01;31:*.zoo=01;31:*.cpio=01;31:*.7z=01;31:*.rz=01;31:*.cab=01;31:*.wim=01;31:*.swm=01;31:*.dwm=01;31:*.esd=01;31:*.jpg=01;35:*.jpeg=01;35:*.mjpg=01;35:*.mjpeg=01;35:*.gif=01;35:*.bmp=01;35:*.pbm=01;35:*.pgm=01;35:*.ppm=01;35:*.tga=01;35:*.xbm=01;35:*.xpm=01;35:*.tif=01;35:*.tiff=01;35:*.png=01;35:*.svg=01;35:*.svgz=01;35:*.mng=01;35:*.pcx=01;35:*.mov=01;35:*.mpg=01;35:*.mpeg=01;35:*.m2v=01;35:*.mkv=01;35:*.webm=01;35:*.ogm=01;35:*.mp4=01;35:*.m4v=01;35:*.mp4v=01;35:*.vob=01;35:*.qt=01;35:*.nuv=01;35:*.wmv=01;35:*.asf=01;35:*.rm=01;35:*.rmvb=01;35:*.flc=01;35:*.avi=01;35:*.fli=01;35:*.flv=01;35:*.gl=01;35:*.dl=01;35:*.xcf=01;35:*.xwd=01;35:*.yuv=01;35:*.cgm=01;35:*.emf=01;35:*.ogv=01;35:*.ogx=01;35:*.aac=00;36:*.au=00;36:*.flac=00;36:*.m4a=00;36:*.mid=00;36:*.midi=00;36:*.mka=00;36:*.mp3=00;36:*.mpc=00;36:*.ogg=00;36:*.ra=00;36:*.wav=00;36:*.oga=00;36:*.opus=00;36:*.spx=00;36:*.xspf=00;36:', 'HOSTTYPE': 'x86_64', 'LESSCLOSE': '/usr/bin/lesspipe %s %s', 'LANG': 'C.UTF-8', 'OLDPWD': '/home/matt/repos/flame-blis', 'VIRTUAL_ENV': '/home/matt/repos/cython-blis/env3.6', 'USER': 'matt', 'PWD': '/home/matt/repos/cython-blis', 'HOME': '/home/matt', 'NAME': 'LAPTOP-OMKOB3VM', 'XDG_DATA_DIRS': '/usr/local/share:/usr/share:/var/lib/snapd/desktop', 'SHELL': '/bin/bash', 'TERM': 'xterm-256color', 'SHLVL': '1', 'LOGNAME': 'matt', 'PATH': '/home/matt/repos/cython-blis/env3.6/bin:/tmp/google-cloud-sdk/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/mnt/c/Users/matt/Documents/cmder/vendor/conemu-maximus5/ConEmu/Scripts:/mnt/c/Users/matt/Documents/cmder/vendor/conemu-maximus5:/mnt/c/Users/matt/Documents/cmder/vendor/conemu-maximus5/ConEmu:/mnt/c/Python37/Scripts:/mnt/c/Python37:/mnt/c/Program Files (x86)/Intel/Intel(R) Management Engine Components/iCLS:/mnt/c/Program Files/Intel/Intel(R) Management Engine Components/iCLS:/mnt/c/Windows/System32:/mnt/c/Windows:/mnt/c/Windows/System32/wbem:/mnt/c/Windows/System32/WindowsPowerShell/v1.0:/mnt/c/Program Files (x86)/Intel/Intel(R) Management Engine Components/DAL:/mnt/c/Program Files/Intel/Intel(R) Management Engine Components/DAL:/mnt/c/Program Files (x86)/Intel/Intel(R) Management Engine Components/IPT:/mnt/c/Program Files/Intel/Intel(R) Management Engine Components/IPT:/mnt/c/Program Files/Intel/WiFi/bin:/mnt/c/Program Files/Common Files/Intel/WirelessCommon:/mnt/c/Program Files (x86)/NVIDIA Corporation/PhysX/Common:/mnt/c/ProgramData/chocolatey/bin:/mnt/c/Program Files/Git/cmd:/mnt/c/Program Files/LLVM/bin:/mnt/c/Windows/System32:/mnt/c/Windows:/mnt/c/Windows/System32/wbem:/mnt/c/Windows/System32/WindowsPowerShell/v1.0:/mnt/c/Windows/System32/OpenSSH:/mnt/c/Program Files/nodejs:/mnt/c/Users/matt/AppData/Local/Microsoft/WindowsApps:/mnt/c/Users/matt/AppData/Local/Programs/Microsoft VS Code/bin:/mnt/c/Users/matt/AppData/Roaming/npm:/snap/bin:/mnt/c/Program Files/Oracle/VirtualBox', 'PS1': '(env3.6) \\[\\e]0;\\u@\\h: \\w\\a\\]${debian_chroot:+($debian_chroot)}\\[\\033\\]\\u@\\h\\[\\033\\]:\\[\\033\\]\\w\\[\\033\\]\\$ ', 'VAGRANT_HOME': '/home/matt/.vagrant.d/', 'LESSOPEN': '| /usr/bin/lesspipe %s', '_': '/home/matt/repos/cython-blis/env3.6/bin/python'}
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/config/bulldozer/bli_cntx_init_bulldozer.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_cntx_init_bulldozer.o -O2 -funroll-all-loops -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang: warning: optimization flag '-funroll-all-loops' is not supported [-Wignored-optimization-argument]
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/config/generic/bli_cntx_init_generic.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_cntx_init_generic.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/config/haswell/bli_cntx_init_haswell.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_cntx_init_haswell.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/config/penryn/bli_cntx_init_penryn.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_cntx_init_penryn.o -O2 -fomit-frame-pointer -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/config/piledriver/bli_cntx_init_piledriver.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_cntx_init_piledriver.o -O2 -fomit-frame-pointer -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/config/sandybridge/bli_cntx_init_sandybridge.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_cntx_init_sandybridge.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/config/steamroller/bli_cntx_init_steamroller.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_cntx_init_steamroller.o -O2 -fomit-frame-pointer -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/zen/1/bli_amaxv_zen_int.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_amaxv_zen_int.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/zen/1/bli_axpyv_zen_int.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_axpyv_zen_int.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/zen/1/bli_axpyv_zen_int10.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_axpyv_zen_int10.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/zen/1/bli_dotv_zen_int.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotv_zen_int.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/zen/1/bli_dotv_zen_int10.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotv_zen_int10.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/zen/1/bli_dotxv_zen_int.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotxv_zen_int.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/zen/1/bli_scalv_zen_int.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_scalv_zen_int.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/zen/1/bli_scalv_zen_int10.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_scalv_zen_int10.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/zen/1f/bli_axpyf_zen_int_8.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_axpyf_zen_int_8.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/zen/1f/bli_dotxf_zen_int_8.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotxf_zen_int_8.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/zen/3/bli_gemm_small.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_gemm_small.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/haswell/3/bli_gemm_haswell_asm_d6x8.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_gemm_haswell_asm_d6x8.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/haswell/3/bli_gemm_haswell_asm_d8x6.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_gemm_haswell_asm_d8x6.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/haswell/3/bli_gemmtrsm_l_haswell_asm_d6x8.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_gemmtrsm_l_haswell_asm_d6x8.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/haswell/3/bli_gemmtrsm_u_haswell_asm_d6x8.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_gemmtrsm_u_haswell_asm_d6x8.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/sandybridge/3/bli_gemm_sandybridge_asm_d8x4.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_gemm_sandybridge_asm_d8x4.o -O3 -mavx -mfpmath=sse -march=corei7-avx -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/sandybridge/3/bli_gemm_sandybridge_int_d8x4.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_gemm_sandybridge_int_d8x4.o -O3 -mavx -mfpmath=sse -march=corei7-avx -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/penryn/1/bli_axpyv_penryn_int.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_axpyv_penryn_int.o -O2 -fomit-frame-pointer -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/penryn/1/bli_dotv_penryn_int.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotv_penryn_int.o -O2 -fomit-frame-pointer -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/penryn/1f/bli_axpy2v_penryn_int.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_axpy2v_penryn_int.o -O2 -fomit-frame-pointer -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/penryn/1f/bli_axpyf_penryn_int.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_axpyf_penryn_int.o -O2 -fomit-frame-pointer -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/penryn/1f/bli_dotaxpyv_penryn_int.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotaxpyv_penryn_int.o -O2 -fomit-frame-pointer -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/penryn/1f/bli_dotxaxpyf_penryn_int.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotxaxpyf_penryn_int.o -O2 -fomit-frame-pointer -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/penryn/1f/bli_dotxf_penryn_int.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotxf_penryn_int.o -O2 -fomit-frame-pointer -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/penryn/3/bli_gemm_penryn_asm_d4x4.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_gemm_penryn_asm_d4x4.o -O2 -fomit-frame-pointer -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/penryn/3/bli_gemmtrsm_l_penryn_asm_d4x4.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_gemmtrsm_l_penryn_asm_d4x4.o -O2 -fomit-frame-pointer -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/penryn/3/bli_gemmtrsm_u_penryn_asm_d4x4.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_gemmtrsm_u_penryn_asm_d4x4.o -O2 -fomit-frame-pointer -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/penryn/3/bli_trsm_l_penryn_asm_d4x4.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_trsm_l_penryn_asm_d4x4.o -O2 -fomit-frame-pointer -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/penryn/3/bli_trsm_u_penryn_asm_d4x4.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_trsm_u_penryn_asm_d4x4.o -O2 -fomit-frame-pointer -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/piledriver/3/bli_gemm_piledriver_asm_d8x3.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_gemm_piledriver_asm_d8x3.o -O2 -fomit-frame-pointer -mfpmath=sse -mavx -mfma -mno-fma4 -march=bdver2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/kernels/bulldozer/3/bli_gemm_bulldozer_asm_d4x6_fma4.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_gemm_bulldozer_asm_d4x6_fma4.o -O2 -funroll-all-loops -mfpmath=sse -mavx -mfma4 -march=bdver1 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang: warning: optimization flag '-funroll-all-loops' is not supported [-Wignored-optimization-argument]
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/bli_cntx_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_cntx_haswell_ref.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_addv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_addv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_amaxv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_amaxv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_axpbyv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_axpbyv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_axpyv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_axpyv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_copyv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_copyv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_dotv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_dotxv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotxv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_invertv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_invertv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_scal2v_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_scal2v_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_scalv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_scalv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_setv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_setv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_subv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_subv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_swapv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_swapv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1/bli_xpbyv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_xpbyv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1f/bli_axpy2v_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_axpy2v_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1f/bli_axpyf_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_axpyf_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1f/bli_dotaxpyv_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotaxpyv_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1f/bli_dotxaxpyf_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotxaxpyf_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1f/bli_dotxf_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_dotxf_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1m/bli_packm_cxk_1er_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_packm_cxk_1er_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1m/bli_packm_cxk_3mis_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_packm_cxk_3mis_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#     clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/ref_kernels/1m/bli_packm_cxk_4mi_ref.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmpdev0t7nm/bli_packm_cxk_4mi_haswell_ref.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_CNAME=haswell -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
# ...
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/ind/bli_ind.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_ind.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/ind/bli_l3_ind.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_l3_ind.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/ind/cntx/bli_cntx_ind_stage.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_cntx_ind_stage.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/ind/oapi/bli_l3_3m4m1m_oapi.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_l3_3m4m1m_oapi.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/ind/oapi/bli_l3_ind_oapi.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_l3_ind_oapi.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/ind/oapi/bli_l3_nat_oapi.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_l3_nat_oapi.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/ind/tapi/bli_l3_ind_tapi.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_l3_ind_tapi.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/thread/bli_pthread.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_pthread.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/thread/bli_thrcomm.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_thrcomm.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/thread/bli_thrcomm_openmp.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_thrcomm_openmp.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/thread/bli_thrcomm_pthreads.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_thrcomm_pthreads.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/thread/bli_thrcomm_single.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_thrcomm_single.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/thread/bli_thread.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_thread.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/thread/bli_thrinfo.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_thrinfo.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/util/bli_util_check.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_util_check.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/util/bli_util_fpa.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_util_fpa.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/util/bli_util_oapi.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_util_oapi.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/util/bli_util_oapi_ba.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_util_oapi_ba.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/util/bli_util_oapi_ex.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_util_oapi_ex.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/util/bli_util_tapi.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_util_tapi.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/util/bli_util_tapi_ba.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_util_tapi_ba.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/util/bli_util_tapi_ex.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_util_tapi_ex.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       clang -c /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/frame/util/bli_util_unb_var1.c -o /var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/tmp1a1ofuse/bli_util_unb_var1.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.0-6" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/darwin-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64
#       Compiler gcc
#       building 'blis.cy' extension
#       creating build/temp.macosx-10.9-x86_64-3.8
#       creating build/temp.macosx-10.9-x86_64-3.8/blis
#       gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/tarrantcarter/miniconda3/include -arch x86_64 -I/Users/tarrantcarter/miniconda3/include -arch x86_64 -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/include -I/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/blis/_src/include/darwin-x86_64 -I/Users/tarrantcarter/miniconda3/include/python3.8 -c blis/cy.c -o build/temp.macosx-10.9-x86_64-3.8/blis/cy.o -std=c99
#       error: $MACOSX_DEPLOYMENT_TARGET mismatch: now "10.7" but "10.9" during configure
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: /Users/tarrantcarter/miniconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/setup.py'"'"'; __file__='"'"'/private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-install-2_k0iuvm/blis/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-record-inovlipv/install-record.txt --single-version-externally-managed --prefix /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-build-env-cuhumo8y/overlay --compile --install-headers /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-build-env-cuhumo8y/overlay/include/python3.8/blis Check the logs for full command output.
#   ----------------------------------------
# ERROR: Command errored out with exit status 1: /Users/tarrantcarter/miniconda3/bin/python /Users/tarrantcarter/miniconda3/lib/python3.8/site-packages/pip install --ignore-installed --no-user --prefix /private/var/folders/ls/47gwjlnd0ng7sn4778s52bz00000gn/T/pip-build-env-cuhumo8y/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'wheel>0.32.0,<0.33.0' Cython 'cymem>=2.0.2,<2.1.0' 'preshed>=2.0.1,<2.1.0' 'murmurhash>=0.28.0,<1.1.0' 'thinc>=7.0.8,<7.1.0' Check the logs for full command output.
# Collecting chatterbot-corpus
#   Using cached chatterbot_corpus-1.2.0-py2.py3-none-any.whl (117 kB)
# Processing /Users/tarrantcarter/Library/Caches/pip/wheels/db/f2/07/5e58b12bc11255c3fc0a0aca89849050a8ec203d8b4a3c52c0/PyYAML-3.13-cp38-cp38-macosx_10_9_x86_64.whl
# Installing collected packages: PyYAML, chatterbot-corpus
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 5.3.1
#     Uninstalling PyYAML-5.3.1:
#       Successfully uninstalled PyYAML-5.3.1
# Successfully installed PyYAML-5.1.2 chatterbot-corpus-1.2.0

# %%
postgres_user = "dsbc_student"
postgres_pw = "7*.8G9QH21"
postgres_host = "142.93.121.174"
postgres_port = "5432"
postgres_db = "cornell_movie_dialogs"

engine = create_engine(
    "postgresql://{}:{}@{}:{}/{}".format(
        postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db
    )
)

dialogs = pd.read_sql_query("select * from dialogs", con=engine)

# no need for an open connection, as we're only doing a single query
engine.dispose()


dialogs.head(10)
# Out:
#    index                                            dialogs
# 0      0  Can we make this quick?  Roxanne Korrine and A...
# 1      1  Well, I thought we'd start with pronunciation,...
# 2      2  Not the hacking and gagging and spitting part....
# 3      3  Okay... then how 'bout we try out some French ...
# 4      4  You're asking me out.  That's so cute. What's ...
# 5      5                                         Forget it.
# 6      6  No, no, it's my fault -- we didn't have a prop...
# 7      7                                           Cameron.
# 8      8  The thing is, Cameron -- I'm at the mercy of a...
# 9      9     Seems like she could get a date easy enough...

# %% [markdown]
# ## First, do some data preprocessing to clean up the data. You can use your solution to the assignment of the Text preprocessing checkpoint.

# %%
dialogs2 = dialogs.drop(columns="index")
dialogs2.head()
# Out:
#                                              dialogs
# 0  Can we make this quick?  Roxanne Korrine and A...
# 1  Well, I thought we'd start with pronunciation,...
# 2  Not the hacking and gagging and spitting part....
# 3  Okay... then how 'bout we try out some French ...
# 4  You're asking me out.  That's so cute. What's ...

# %%
# Utility function for standard text cleaning
def text_cleaner(text):
    type(text)
    # Visual inspection identifies a form of punctuation that spaCy does not
    # recognize: the double dash --.  Better get rid of it now!
    text = re.sub(r"--", " ", text)
    text = re.sub("[\[].*?[\]]", "", text)
    text = re.sub(r"(\b|\s+\-?|^\-?)(\d+|\d*\.\d+)\b", " ", text)
    text = " ".join(text.split())
    return text

# %%
dialogs3 = []

for dialog in dialogs2["dialogs"]:
    cleaned = text_cleaner(dialog)
    dialogs3.append(cleaned)

dialogs4 = pd.DataFrame(dialogs3, columns=["dialogs"])
dialogs4.head()
# Out:
#                                              dialogs
# 0  Can we make this quick? Roxanne Korrine and An...
# 1  Well, I thought we'd start with pronunciation,...
# 2  Not the hacking and gagging and spitting part....
# 3  Okay... then how 'bout we try out some French ...
# 4  You're asking me out. That's so cute. What's y...

# %%
nlp = spacy.load("en", disable=["parser", "ner"])
nlp.add_pipe(nlp.create_pipe("sentencizer"))
nlp.max_length = 20000000
doc = nlp(" ".join(dialogs4["dialogs"]))

# %%
print("The doc object is a {} object.".format(type(doc)))
print("It is {} tokens long".format(len(doc)))
print("The first three tokens are '{}'".format(doc[:3]))
print("The type of each token is {}".format(type(doc[0])))
# Out:
# The doc object is a <class 'spacy.tokens.doc.Doc'> object.
# It is 4162681 tokens long
# The first three tokens are 'Can we make'
# The type of each token is <class 'spacy.tokens.token.Token'>

# %%
# make dialog sentences of more than one word
sents = [sent.text for sent in doc.sents if len(sent.text) > 1]

# %% [markdown]
# ## Develop a chatbot using this corpus. In doing this, you're free to choose a chatbot development library like ChatterBot or write your own code from scratch.

# %%
GREETING_INPUTS = ["hello", "hi", "greetings", "what's up", "hey"]
GREETING_RESPONSES = ["hello", "hi", "hey", "hi there"]


def greeting(sentence):
    for word in sentence.split():
        if word.lower() in GREETING_INPUTS:
            return random.choice(GREETING_RESPONSES)

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer, ChatterBotCorpusTrainer
from chatterbot.conversation import Statement

# %%
# create a chatbot
chatbot = ChatBot("Dialogs")
# this is to remove the accumulated knowledge base
chatbot.storage.drop()

# create a new trainer for the chatbot
trainer = ListTrainer(chatbot)

# train the chatbot
trainer.train(sents)
# Out:
# List Trainer: [####################] 100%

# %% [markdown]
# ## Start a conversation with your chatbot, and discuss its strengths and weaknesses.

# %%
import random

# %%
bot_name = "Movie Quoting Machine"
print(
    f"{bot_name}: I will try to respond to you reasonably. If you want to exit, type bye."
)

# Below is the chatting
while True:

    user_input = input("User: ")
    user_input = user_input.lower()

    if user_input != "bye":
        if user_input == "thanks" or user_input == "thank you":
            break
            print(f"{bot_name}: You're welcome.")
        else:
            if greeting(user_input) != None:
                print(f"{bot_name}: " + greeting(user_input))
            else:
                print(f"{bot_name}: ", end="")
                print(chatbot.get_response(user_input))
    else:
        print(f"{bot_name}: Bye! It was a great chat.")
        break
# Out:
# Movie Quoting Machine: I will try to respond to you reasonably. If you want to exit, type bye.
# User: hello
# Movie Quoting Machine: hi
# User: how are you?
# Movie Quoting Machine: Takin' a bath.
# User: sounds fun
# Movie Quoting Machine: Yeah.
# User: you busy?
# Movie Quoting Machine: I figure we'll get over to the hotel... get checked in, cleaned up... then I'd like to do something I've been thinking about for a long time.
# User: What is that thing?
# Movie Quoting Machine: I think that thing is Ben.
# User: Who is Ben?
# Movie Quoting Machine: You never wanted to go out with 'me, did you?
# User: No I don't
# Movie Quoting Machine: The sub-surface structure shows that it was deliberately buried about four million years ago.
# User: that was akward
# Movie Quoting Machine: Forget French.
# User: your confusing me
# Movie Quoting Machine: Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.
# User: That's good to know. I guess...
# Movie Quoting Machine: Well, it's just for the past two weeks there have been some extremely odd things happening at Clavius.
# User: This is too much for me. I can't follow you.
# Movie Quoting Machine: Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.
# User: Now your just repeating yourself. Good-bye
# Movie Quoting Machine: What good stuff?
# User: bye
# Movie Quoting Machine: Bye! It was a great chat.
